# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Funzioni matematiche**

# %%
array = np.array([0.,1.,2.,4.,5.])

# %% [markdown]
# Calcoliamo l'esponenziale dell'array con la funzione $e^x$. Questo è un esempio di *math text*.
# Per esempio in Math Text posso scrivere le frazioni: $\frac{3}{2}$

# %%
np.exp(array)  # e^0, e^1, e^2 ecc..ecc..    EXP per gli esponenziali
# Out:
# array([  1.        ,   2.71828183,   7.3890561 ,  54.59815003,
#        148.4131591 ])

# %%
x = np.linspace(-5, 5, 400) #array di valory equispaziati tra -5 e 5

# %%
y = np.exp(x)
plt.plot(x, y)

# %%
x = np.linspace(0, 4*np.pi, 400)  #np.pi vuol dire PIgreco
y = np.sin(x) 
plt.plot(x,y)

# %%
y[y > 0.5] = 0.5 #indicizzazione boolean, evidenziamo i punti maggiori di 0,5 e solo per quelli assegnamo 0,5 per questo escono le parti piatte sopra perche superano 0.5
plt.plot(x,y)

# %%
x = np.linspace(-20*np.pi, 20*np.pi, 10000)
y = np.sin(x) / x
plt.plot(x, y)

# %% [markdown]
# distribuzione Gaussiana, Caratterizzata da una posizione di dove si trova il massimo che è la media, quindi il valore medio

# %%
n_persone = 20
altezze_cm = np.random.normal(175, 1, n_persone) #piu è piccolo il numero centrale più i valori saranno generati vicino a 175, si chiama deviazione standard
np.round(altezze_cm, 1)
# Out:
# array([176.5, 176.1, 175.4, 177.2, 174.8, 175.6, 175.6, 174.9, 173.8,
#        174.6, 175.9, 174.5, 174.1, 175.7, 175.7, 175. , 175.3, 177. ,
#        175.4, 174.6])
